# %%
pip install pymupdf faiss-cpu sentence-transformers langchain
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.25.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.4 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.23)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.51 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.52)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.31)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.40)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.51->langchain) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.1.31)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.51->langchain) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Downloading pymupdf-1.25.5-cp39-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (20.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 40.9 MB/s eta 0:00:00
# Downloading faiss_cpu-1.10.0-cp311-cp311-manylinux_2_28_x86_64.whl (30.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.7/30.7 MB 16.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 26.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 25.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 16.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 909.4 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.6 MB/s eta 0:00:00
# Installing collected packages: pymupdf, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, faiss-cpu, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed faiss-cpu-1.10.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pymupdf-1.25.5

# %%
pip install transformers openai
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.75.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.30.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.13.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)

# %%
import fitz
def extract_pdf(path):
    doc = fitz.open(path)
    text = ""
    for i in doc:
        text+=i.get_text()
    return text

path = "/content/Research Paper - Chirag.pdf"
extracted = extract_pdf(path)
print(extracted)
# Out:
# Smart Infant Care System: Integrating IoT, AI, and Automation
# for Adaptive Monitoring and Enhanced Comfort
#
#
# Chirag N                                                                                           S Vijayalakshmi
# Department of Data Science​
# ​
# ​
# ​
# ​
# ​
#        Associate Professor
# Christ University, India                                                                                                                                      Department of Data Science
#  ​
# chirag.n3012@gmail.com                                                                                                                                 CHRIST University, India
#  ​
#                                                                                                                                 ​
#    ​
#       s.vijayalakshmi@christuniversity.in
#
#      ​
# ​
# ​
# ​
# ​
# ​
# ​
# ​
# ​
#
#
#
# Abstract
# This paper explores the improvements in the clever infant cradle system, focusing on improvements
# designed to cater to the various desires of running parents through providing comprehensive little one
# care. As the demand for automatic, smart systems in childcare continues to upward thrust, there may be
# an increasing urgency for extra superior functionalities that decorate protection, consolation, and
# convenience for infants and parents. This paper severely evaluates current literature on shrewd cradle
# systems from various resources, highlighting key research contributions which have driven the
# improvement of clever cradle technologies, inclusive of integration with IoT (internet of things), machine
# learning algorithms, and mobile applications interfaces that allow far off tracking and manipulation.
# Features in the infant cradle systems like advanced cry detection, lullaby recommendations and dynamic
# camera surveillance, also are addressed. The intention of this paper is to offer a clear path for destiny
# research and improvement that align with the evolving demands of contemporary childcare.
#
#
# Introduction
# Looking after a child in recent times is a huge
# task for parents especially when both dad and
# mom are working whilst techs like smart
# homes and healthcare have superior results,
# we've no longer seen a tremendous deal of
# development in using this technology to help
# parents with their babies.
# Many infant monitors are pretty fundamental.
# They often simply measure such things as
# room temperature or attempt to wager why a
# baby is crying, but they do not certainly
# understand each baby's specific desires. Those
# monitors can not continually adapt and
# alternate as the baby grows and develops.
# Believe in a system that could surely
# understand your baby's desires, not simply
# their cries. it could study their patterns,
# recognize their one of a kind cries, or even
# predict while they could need a diaper alternate
# or a feeding. This generation may want to offer
# mothers and fathers precious insights and
# peace of mind, permitting them to spend more
# excellent time with their kids.
# This paper introduces a holistic, clever little
# one Care gadget that addresses those obstacles
# with the aid of combining IoT, AI, and cloud
# computing technology. The proposed device
# incorporates dynamic cradle automation, cry
# purpose category, temperature detection, and a
# set of environmental monitoring functions.
# Key improvements encompass adaptive swing
# speed adjustment, puke detection, mosquito
# repellent integration, and personalized lullaby
# recommendations based on historical statistics.
# real-time
# video
# surveillance
# and
# gesture-primarily based controls similarly
# decorate the interactive nature of the machine,
# even as cloud analytics deliver predictive
# insights for proactive caregiving.
# By
# integrating
# advanced
# knowledge
# of
# machine and deep learning models and
# automation,
# this
# framework
# aspires
# to
# transform little care from reactive supervision
# to proactive, records-driven nurturing. It
# empowers mother and father with faraway
# monitoring,
# well
# timed
# indicators,
# and
# customizable interactions, thereby presenting
# peace of thoughts and lowering manual
# intervention. The following sections detail the
# system’s
# architecture,
# implementation,
# experimental results, and future enhancements
# to improve adaptability, accuracy, and user
# experience, ultimately aiming to create a more
# harmonious and supportive environment for
# both parents and their children.
# Emerging technologies, such as APDS9960
# sensors for gesture recognition, offer promising
# advancements in understanding infant behavior
# and movement patterns, paving the way for
# more intuitive and responsive caregiving
# environments.
#
#
# System Design and Architecture
# Technologies and Architecture Overview
#
# The proposed smart toddler Care system
# integrates superior IoT hardware and software
# program
# components
# to
# deliver
# complete,
# adaptive
# tracking.
# Every
# technology
# is
# purposefully selected to beautify actual-time
# responsiveness,
# nearby
# inference,
# and
# statistics-driven insights. underneath is a detailed
# description of how those technologies are applied:
#
# a.​ Dynamic Camera Feature:
# ●​ ESP32 Microcontroller: The core of
# the
# device,
# answerable
# for
# coordinating the camera's role, making
# sure smooth adjustments.
# ●​ Servo automobiles: The camera is
# fixed on a servo motor, it enables the
# dynamic repositioning of the camera
# according to the infant's movements,
# making sure that the camera usually
# captures the infant even if the infant
# tries
# to
# move
# out
# of
# camera's
# proximity.
# ●​ PIR motion sensor: This sensor is used
# to detect the baby's movement. This
# sensor is used as an addition to reduce
# the processing power and quickly alert
# the ESP32 microcontroller to trigger
# the servo motors.
# ●​ MobileNetV2 item Detection version:
# This is deployed to detect and track the
# infant's position in real-time using
# efficient deep learning algorithms.
# This model is optimized for devices
# like ESP32. This ensures the camera
# responds quickly and accurately to the
# baby’s movements making it dynamic.
#
# b.​ Cry-Based Swing Activation:
# ●​ Cry
# Detection:
# The
# gadget
# continuously monitors the child’s cries
# through a sensor and boosts the
# microphone signal using
# Adafruit
# MAX9814 . It makes use of the
# Yamnet model to classify cry sounds
# and decide the reason behind the
# infant's cry, which include the depth
# and frequency of the sound.
# ●​ Threshold for Activation: If the cry
# exceeds a set frequency or a period,
# the swing mechanism will be triggered
# indicating the distress within the
# infant.
# ●​ Dynamic Swing Adjustment: The
# ESP32 microcontroller adjusts the
# swing velocity based
# on the cry
# depth.It makes use of a dc motor to
# dynamically swing the cradle. It would
# initially begin with mild movement,
# gradually increasing the velocity of the
# swing.
# ●​ Feedback
# Loop:
# As
# the
# crying
# subsides, the machine detects the
# change in sound frequency via the cry
# model and may reduce or gradually
# stop the swing, making sure the
# infant’s
# consolation
# without
# over-stimulation.
#
# c.​ Cry Detection for Cause Classification:
# Adafruit MAX9814 (audio processing) :
# This sensor helps the microphone to capture
# the infant's cry with variable sensitivity and
# automated gain(automatically adjusts the
# sensitivity of the microphone based on the
# intensity and frequency of the incoming
# sound).
# wavesurfer.js (javascript library) is also
# used by integrating it with this sensor for
# visualizing and analysing audio signals.
# This ensures that the cry of all varieties
# irrespective of the intensity of the sound and
# its frequency is accurately picked by the
# microphone. This guarantees steady overall
# performance even in noisy environments.
# YAMNet: YAMNet is a deep learning
# model which is used to classify the cry
# sounds
# into predefined classes(hunger,
# burping, belly pain etc).
# Once the YAMNet model is built it now
# needs to be converted into a TensorFlow lite
# model. Later the TensorFlow lite model
# must be optimized in order to integrate in
# ESP 32. The optimization is executed by
# using a quantization technique during the
# conversion process to reduce the model size
# and increase the speed.
# ESP32: It serves as the heart for the entire
# system. It handles all the IoT related tasks
# as it has got a built in wifi and bluetooth
# module. It allows seamless conversation
# between cradle and other intelligent sensors
#
# d.​ APDS9960 sensor
# It is a gesture, ambient light and proximity
# sensor. It is capable of integrating multiple
# functionalities into one compact module. In
# the smart baby cradle system, this sensor
# can be used to detect gestures, can be used
# as an alternative for PIR sensor, also for
# adjusting the ambience and intensity of the
# room light remotely by the parents.
# e.​ HiveMQTT
# It is a light weight, reliable messaging
# protocol
# designed
# for
# real
# time
# communication between IoT  devices. It
# uses the MQTT protocol as it is suitable for
# environments with low bandwidth or
# unreliable networks.
# f.​
# Ngork for live video streaming
# ngrok is used to tunnel local servers and
# offer secure external access to video feeds
# and other real-time facts from the ESP32
# microcontroller and camera machine.
# Mother and father can securely view live
# video streams from the infant’s cradle via a
# web app or a mobile application. The
# camera feeds are controlled by the ESP32.
# g.​ DFPlayer Mini
# It is a MP3 player module when integrated
# with a microcontroller(ESP32) used for
# automatically
# playing
# comforting
# and
# soothing music based on the type of cry. A
# pre recorded lullaby from the parents is also
# used to comfort the infant
#
# h.​ Ultrasonic Mosquito Repellent
# High frequency sound waves are generated
# using piezoelectric transducers. They have a
# frequency in the range 20 Khz to 65 Khz
# which are uncomfortable to mosquitos and
# cause them to leave the area.
#
#
# Hardware
# and
# Software
# Implementation
# a.​ Dynamic Camera System
#  The Dynamic digital camera function in
# our smart infant system is a sophisticated
# mechanism designed to adjust the camera
# dynamically based on the position of the
# baby. This requires usage of several
# hardware and complicated software.
# The Dynamic camera feature in our smart
# infant system is a complicated mechanism
# designed to alter the digicam dynamically
# based totally on the position of the infant.
# The ESP32 microcontroller serves as the
# heart of our system and is responsible for
# the integrated dynamic camera module. It
# takes information from sensors like PIR
# sensor, camera and MobileNet model to
# process information for smooth movement
# of the camera based on the infant's position.
# The built-in wifi module and Bluetooth
# module allows real time communication
# which enables remote monitoring and
# controls.
# The digital camera is set up on a servo
# motor-based pan-tilt platform that is capable
# of moving in horizontal and vertical
# directions.
#  This setup guarantees that the camera can
# follow the baby’s position regardless of its
# movements within the cradle. Servo motors
# are driven by pulse width modulation
# (PWM)
# signals,
# which
# the
# ESP32
# microcontroller generates for precise and
# smooth
# repositioning . This dynamic
# mechanism helps in continuous capturing of
# infants
# by adjusting the camera angle,
# maintaining real time focus on the infant.
# A PIR  sensor improves systems efficiency
# by  detecting movement and triggering the
# dynamic camera system. For the reason that
# detection is primarily based on infrared
# radiation the sensor can detect even though
# the movement is subtle. Each time a motion
# is detected, the sensor gives a signal that
# suggests movement has been detected.This
# signal in turn triggers the dynamic camera
# module.
# PIR sensors consume much less power
# making them best for our smart infant care
# system. Once the ESP32 gets the signal
# from the PIR sensor, it triggers the servo
# motor which is responsible for positioning
# the camera to hold the infant in view.
# The MobileNetV2 object detection model,
# which is optimized for deployment on the
# ESP32, is used to tune the  position of the
# infant in the video frame. Once the PIR
# sensor detects movement and sends the
# signal to the model, MobileNetV2 model in
# turn processes the incoming video stream to
# track the exact position of the infant inside
# the cradle. On the basis of the model's
# output, the ESP32 microcontroller brings
# essential changes to the orientation of the
# camera and instructs the servo motor to
# reposition the camera accordingly. Thus,
# making the camera dynamic in nature. This
# model's weights are reduced by converting
# it into a TensorFlow light model and is
# optimized using quantization techniques to
# ensure efficient operations on an ESP32.
# b.​ Cry based Swing Activation
# The Cry-based swing activation is
# designed
# to
# respond
# to
# infant's
# discomfort by activating the swinging
# mechanism in the cradle. The swing is
# dynamic which provides comfort and
# soothing experience for the infant.
# Continuous audio monitoring and
# advanced
# sound
# classification
# is
# needed to deliver a precise mechanism.
# The Cry-based Swing Activation is
# designed to respond to an infant's
# distress by activating the swinging
# mechanism in the cradle. The swing is
# dynamic which provides comfort and
# soothing experience for the infant.
# Continuous audio monitoring and
# advanced
# sound
# classification
# is
# needed to deliver a precise mechanism.
# The
# ESP32
# microcontroller
# is
# responsible for handling real-time
# audio processing and motor control.
# The audio signal (cry) is captured
# using  Adafruit MAX9814 integrated
# microphone. This microphone module
# is equipped with automatic gain
# control (AGC), allowing it to detect
# and amplify cry sounds of various
# intensities. AGC automatically adjusts
# the sensitivity of the microphone
# depending on the loudness of the
# incoming sound, ensuring that each
# faint and intense cries are captured
# accurately without guide tuning. This
# functionality
# is
# critical
# for
# environments with fluctuating noise,
# because
# it
# guarantees
# consistent
# performance and reliable cry detection.
# As soon as the audio signal is
# processed,
# the
# device
# uses
# the
# YAMNet
# model
# to
# classify
# the
# detected cry sounds. YAMNet is a
# deep learning model trained on an
# extensive range of audio data, making
# it
# suitable
# for
# recognizing
# and
# classifying specific kinds of cries ,
# YAMNet
# distinguishes
# between
# various reasons for distress, like
# hunger, belly pain, or tiredness. The
# classified results allow the system to
# determine
# the
# correct
# response,
# improving
# the
# personalized
# care
# experience for the infant.
#
# The model continuously monitors the
# intensity of the baby’s cry. If the cry
# exceeds a predefined threshold for
# loudness or duration, it triggers the
# cradle’s swing mechanism. A DC
# motor drives the swing, imparting
# easy, controlled movement. It initially
# starts with the  gentle movement of the
# cradle to keep away from startling the
# child. The ESP32 microcontroller
# dynamically adjusts the swing velocity
# based on the ongoing evaluation of the
# cry’s frequency and depth. If the cry
# intensifies,
# the
# swing
# pace
# will
# increase to offer greater soothing
# movement. If the infant still continues
# to cry then the mother and father are
# alerted through a notification on their
# mobile software.
# A feedback loop is crucial to this
# system, continuously evaluating the
# little one’s cry in real-time. As the cry
# intensity reduces, indicating that the
# infant is calming down, the gadget
# gradually reduces the swing velocity.
# When the cry intensity falls under the
# minimal
# threshold,
# the
# swinging
# movement
# stops
# altogether,
# maintaining power and preventing
# overstimulation.
# This
# adaptive
# manipulative technique guarantees that
# the
# little
# one’s
# consolation
# is
# prioritized.
# c.​ Cry
# Detection
# for
# Cause
# Classification:
# This is a feature in our system which
# basically
# analyzes
# cry
# sound,
# determines the reason behind the cry
# and adapts the cradle's response
# therefore and additionally sends a
# notification to the parents mobile
# application. This capability requires in
# depth audio processing, real time
# visualization and machine learning
# interference all taken care through the
# ESP32 microcontroller.
#
# Adafruit
# MAX9814
# integrated
# microphone is used to precisely pick
# signals from the infant's cry. AGC
# dynamically adjusts the sensitivity of
# the microphone in order that the
# microphone may not miss the feeble
# crying sounds of the infant. This is a
# completely critical step in collecting
# the signal, due to the fact if the
# microphone fails to pick the feeble
# indicators then it'd lead to the incorrect
# prediction by the model. Once the
# audio is captured the system uses
# wavesurfer.js
# for
# real
# time
# visualization
# of
# audio
# alerts.
# It
# converts the audio waveforms into
# graphical illustration making it simpler
# for the developers to investigate the
# cry pattern. This visible feedback can
# also be used to further tune the model
# and boost the accuracy of the model.
#
# The audio signal is further classified
# with the help of YAMNet. This deep
# learning model identifies cry types
# associated with common infant desires
# such as hunger, tiredness, belly pain,
# burping or pain. This model has to be
# converted into a TensorFlow lite model
# and needs to be optimized using
# quantization techniques. This helps in
# reducing the weights used to train the
# model and ultimately reduces the size
# of the model as it becomes easy to
# integrate
# the
# model
# into ESP32
# microcontroller without compromising
# on the accuracy.
# The ESP32 microcontroller receives
# the
# data
# from
# the
# microphone,
# performs analysis from the optimized
# model and interprets the cry type
# results to determine an appropriate
# action. For example if the gadget
# detects the infant's cry connected to
# hunger then the system can alert the
# mother and father through a mobile
# application, while a cry related to
# discomfort might cause automatic
# swinging or soothing voice playback.
#
# d.​ Ultrasonic Mosquito Repellent
# The Ultrasonic Mosquito Repellent
# feature in the smart cradle  gives a
# chemical-free,
# energy
# efficient
# technique to shield infants from
# mosquito
# bites,
# an
# important
# consideration for health. This feature
# uses
# sound
# waves
# of
# higher
# frequencies that prevent the mosquitos
# from moving away from the infant.
# Piezoelectric transducer is used in this
# system, a device which is able to
# convert electric power into mechanical
# vibrations to produce sound waves.
# This transducer can generate ultrasonic
# frequency within the range of 20khz to
# 65khz. The frequency of this variety is
# subtle to people and most of the family
# pets but is simply uncomfortable to
# mosquitoes. When mosquitoes get
# exposed to these high frequency
# waves, they experience disorientation
# and discomfort, forcing them to move
# away from the sound supply.
# ESP32 microcontroller plays a crucial
# role in regulating this operation. This
# system is programmed to continuously
# emit high frequency waves during
# periods when the infant is sleeping. It
# can also be scheduled according to the
# parents' will.
# Conclusion
# The smart infant care system presented
# in this paper uses technologies like
# Artificial
# Intelligence,
# Internet of
# Things and automation generation to
# provide overall adaptive monitoring
# and more ideal comfort for infants,
# addressing
# the
# need
# for smarter
# childcare solutions. This system is a
# combination of  multiple technologies
# like a dynamic camera device, cry
# based swing activation, cry type based
# classification, and ultrasonic mosquito
# repellent,
# the
# system
# goes
# past
# conventional baby monitoring devices,
# supplying a proactive and customized
# caregiving experience. Each and every
# component of the system contributes to
# a holistic method that in particular
# makes
# a
# speciality
# of
# safety
# consolation of the infant and the
# benefit of working parents.
# The dynamic camera system, with its
# ESP32-controlled servo motors and
# PIR sensors, ensures continuous visual
# tracking of the infant’s position,
# adapting automatically to movement.
# The
# cry-based
# swing
# activation
# responds intelligently to varying cry
# intensities,
# dynamically
# adjusting
# swing speed to soothe the infant while
# conserving energy. Cry classification,
# leveraging YAMNet and TensorFlow
# Lite, provides insight into the baby’s
# needs, enabling targeted actions and
# real-time
# alerts
# to
# parents.
# The
# chemical-free
# ultrasonic
# mosquito
# repellent enhances health and safety,
# using piezoelectric transducers to emit
# high-frequency sound waves that drive
# mosquitoes away without discomfort
# to humans.
# By combining real-time monitoring,
# smart learning, and IoT technology in
# one system, this smart baby care
# solution makes big improvements over
# traditional cradles. It helps parents feel
# more
# at ease by keeping them
# informed and providing a safer, more
# comforting environment for their baby,
# responding
# to
# their
# needs in a
# thoughtful and caring way.
# References
# [1]  A. S. Hodel, “Rapid infant prefrontal cortex
# development
# and
# sensitivity
# to
# early
# environmental experience”, Develop. Rev.,
# vol. 48, pp. 113–144, Jun. 2018. Accessed:
# Oct.
# 25,
# 2024.
# [Online].
# Available:
# https://doi.org/10.1016/j.dr.2018.02.003
# [2]  S.-M. Chae, J.-Y. Yeo, and N.-r. Chung, “A
# qualitative study of the sleep ecology of
# infants under 2 years old and their mothers in
# South Korea”, Sleep Health, vol. 8, no. 1, pp.
# 101–106, Feb. 2022. Accessed: Oct. 25, 2024.
# [Online].
# Available:
# https://doi.org/10.1016/j.sleh.2021.10.013
# [3]   D. R. Kiran, “Internet of things”, in Production
# Planning and Control. Elsevier, 2019, pp.
# 495–513. Accessed: Oct. 25, 2024. [Online].
# Available:
# https://doi.org/10.1016/b978-0-12-818364-9.0
# 0035-4
# [4]   W. A. Jabbar, H. K. Shang, S. N. I. S. Hamid,
# A. A. Almohammedi, R. M. Ramli, and M. A.
# H. Ali, “IoT-BBMS: Internet of Things-Based
# Baby Monitoring System for Smart Cradle”,
# IEEE Access, vol. 7, pp. 93791–93805, 2019.
# Accessed: Sep. 14, 2024. [Online]. Available:
# https://doi.org/10.1109/access.2019.2928481
# [5]  N. L. Pratap, K. Anuroop, P. N. Devi, A.
# Sandeep, and S. Nalajala, “IoT based smart
# cradle for baby monitoring system”, in 2021
# 6th Int. Conf. Inventive Computation Technol.
# (ICICT), Coimbatore, India, Jan. 20–22, 2021.
# IEEE, 2021. Accessed: Sep. 10, 2024.
# [Online].
# Available:
# https://doi.org/10.1109/icict50816.2021.93586
# 84
# [6]
# V. Karad, “Cradle monitoring system for
# babies: Baby sentry”, Indian Patent.
# [7]  Y. S. S. Reddy, K. S. V. Vamsi, G. Akhila, A.
# Poonati, and K. Jayanth, “An Automated
# Baby Monitoring System”, Int. J. Eng. Adv.
# Technol., vol. 10, no. 6, pp. 114–119, Aug.
# 2021. Accessed: Sep. 11, 2024. [Online].
# Available:
# https://doi.org/10.35940/ijeat.f3058.0810621
# [8]
# H. Alam et al., “IoT Based Smart Baby
# Monitoring System with Emotion Recognition
# Using Machine Learning”, Wireless Commun.
# Mobile Comput., vol. 2023, pp. 1–11, Apr.
# 2023. Accessed: Sep. 11, 2024. [Online].
# Available:
# https://doi.org/10.1155/2023/1175450
# [9]  D. Sontakke, A. Kand, S. Sawant, and M.
# Annamalai, “IOT Based Baby Monitoring
# System for Smart Cradle”, Int. Res. J. Innov.
# Eng. Technol. (IRJIET), vol. 8, no. 3, pp.
# 232–236, Mar. 2024. Accessed: Sep. 2, 2024.
# [Online].
# Available:
# https://doi.org/10.47001/IRJIET/2024.803033
# [10]  Kannan P, A. Devaraj, B.Pradheep T Rajan,
# Swathira P K, Subhikshaa Jayaranim, and
# Shebna V, “IoT Based Smart Cradle Using
# PI”, in Recent Trends in Intensive Computing.
# IOS Press, 2021. Accessed: Sep. 12, 2024.
# [Online].
# Available:
# https://doi.org/10.3233/apc210268
# [11]   X. Long et al., “An efficient heuristic method
# for infant in/out of bed detection using
# video-derived motion estimates”, Biomed.
# Phys. & Eng. Exp., vol. 4, no. 3, p. 035035,
# Apr. 2018. Accessed: Sep. 11, 2024.
# [Online].
# Available:
# https://doi.org/10.1088/2057-1976/aab85f
# [12]   F. Fahmi, W. Shalannanda, I. Zakia, and E.
# Sutanto, “Design of an IoT-based smart
# incubator that listens to the baby”, IOP Conf.
# Ser.: Mater. Sci. Eng., vol. 1003, p. 012153,
# Dec. 2020. Accessed: Aug. 31, 2024.
# [Online].
# Available:
# https://doi.org/10.1088/1757-899x/1003/1/01
# 2153
# [13]    F. Manganiello. “Micmon.” GitHub. [Online].
# Available:
# https://github.com/blacklight/micmon
# [14]   S. A. Alswedani and F. E. Eassa, “A Smart
# Baby Cradle Based on IoT”, Int. J. Comput.
# Sci. Mobile Comput., vol. 9, no. 7, pp.
# 64–76, Jul. 2020.
# [15]     K. S. Alishamol, T. T. Fousiya, K. J. Babu,
# M. Sooryadas, and L. Mary, “System for
# Infant Cry Emotion Recognition using
# DNN”, in 2020 Third Int. Conf. Smart Syst.
# Inventive Technol. (ICSSIT), Tirunelveli,
# India, Aug. 20–22, 2020. IEEE, 2020.
# Accessed:
# Aug.
# 31,
# 2024.
# [Online].
# Available:
# https://doi.org/10.1109/icssit48917.2020.921
# 4198
# [16]    O. F. Reyes-Galaviz and C. A. Reyes-García,
# “A System for the Processing of Infant Cry
# to Recognize Pathologies in Recently Born
# Babies with Neural Networks”, in SPECOM
# 2004: 9th conf., St. Petersburg, Russia, Sep.
# 20–22, 2004.
# [17]
# “Infant Cry Classification And Pain Level
# Prediction”, Indian Patent RNS Institute of
# Technology, Aug. 9, 2024.
# [18]     R. P. R. Kumar, P. Sanjeeva, D. Reddy, and
# A. Reddy, “Smart Monitoring System for
# Physically Handicapped Infants using IoT”,
# E3S Web Conf., vol. 391, p. 01161, 2023.
# Accessed:
# Sep.
# 13,
# 2024.
# [Online].
# Available:
# https://doi.org/10.1051/e3sconf/2023391011
# 61
# [19]    S. Matsunaga, S. Sakaguchi, M. Yamashita, S.
# Miyahara, S. Nishitani, and K. Shinohara,
# “Emotion detection in infants cries based on
# a
# maximum
# likelihood
# approach”,
# in
# Interspeech 2006. ISCA: ISCA, 2006.
# Accessed:
# Sep.
# 13,
# 2024.
# [Online].
# Available:
# https://doi.org/10.21437/interspeech.2006-50
# 6
# [20]    P. Bhasha, T. Pavan Kumar, K. K. Baseer, and
# V. Jyothsna, “An IoT-Based BLYNK Server
# Application for Infant Monitoring Alert
# System to Detect Crying and Wetness of a
# Baby”, in Advances in Intelligent Systems
# and
# Computing.
# Singapore:
# Springer
# Singap., 2021, pp. 55–65. Accessed: Sep. 14,
# 2024.
# [Online].
# Available:
# https://doi.org/10.1007/978-981-33-6176-8_
# 7
#
#
# ​

# %%
#Splitting the document into chunks
from langchain.text_splitter import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
texts = splitter.split_text(extracted)

# %%
#Converting texts into embeddings
import faiss
from sentence_transformers import SentenceTransformer
import numpy as np
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(texts, show_progress_bar=True)
dimension = embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(np.array(embeddings))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def search_query(query, k=5):
    query_embedding = model.encode([query])
    distances, indices = index.search(np.array(query_embedding), k)
    results = [texts[i] for i in indices[0]]
    return results

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("google/flan-t5-base")
gen_model = AutoModelForSeq2SeqLM.from_pretrained("google/flan-t5-base")

def answer_query(query):
    context_chunks = search_query(query)
    context = "\n\n".join(context_chunks)

    prompt = f"""Answer the question based on the context below:\n\nContext:\n{context}\n\nQuestion: {query}\nAnswer:"""

    inputs = tokenizer(prompt, return_tensors="pt", max_length=1024, truncation=True)
    outputs = gen_model.generate(**inputs, max_new_tokens=256)
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer
# Out:
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
question = "what is APDS9960 sensor?"
print(answer_query(question))
# Out:
# gesture, ambient light and proximity sensor
